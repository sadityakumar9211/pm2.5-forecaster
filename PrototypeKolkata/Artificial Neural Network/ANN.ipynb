# %% [markdown]
# # Artificial Neural Network
# ### Apply ML algorithms
# Linear Regression
# Lasso Regression
# Decision Tree Regressor
# KNN Regressor
# RandomForestRegressor
# Xgboost Regressor
# Huperparameter Tuning
# ANN- Artificial Neural Network

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('../Data/Real-Data/Real_Combine.csv')

# %%
df.shape
# Out:
# (775, 9)

# %%
## Check for null values

sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot: >

# %%
df=df.dropna()

# %%
X=df.iloc[:,:-1] ## independent features
y=df.iloc[:,-1] ## dependent features

# %%
## check null values
X.isnull()
# Out:
#          T     TM     Tm    SLP      H     VV      V     VM
# 0    False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...
# 770  False  False  False  False  False  False  False  False
# 771  False  False  False  False  False  False  False  False
# 772  False  False  False  False  False  False  False  False
# 773  False  False  False  False  False  False  False  False
# 774  False  False  False  False  False  False  False  False
#
# [775 rows x 8 columns]

# %%
y.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 770    False
# 771    False
# 772    False
# 773    False
# 774    False
# Name: PM 2.5, Length: 775, dtype: bool

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                T        TM        Tm       SLP         H        VV         V  \
# T       1.000000  0.935524  0.957816 -0.757420  0.266486  0.718663  0.437618
# TM      0.935524  1.000000  0.822246 -0.602902 -0.000672  0.694784  0.355071
# Tm      0.957816  0.822246  1.000000 -0.811434  0.462392  0.671069  0.441991
# SLP    -0.757420 -0.602902 -0.811434  1.000000 -0.541203 -0.563667 -0.450169
# H       0.266486 -0.000672  0.462392 -0.541203  1.000000  0.071798  0.164732
# VV      0.718663  0.694784  0.671069 -0.563667  0.071798  1.000000  0.388416
# V       0.437618  0.355071  0.441991 -0.450169  0.164732  0.388416  1.000000
# VM      0.276918  0.221702  0.279698 -0.292371  0.088698  0.293956  0.827395
# PM 2.5 -0.730732 -0.559624 -0.794618  0.701662 -0.507403 -0.498137 -0.446214
#
#               VM    PM 2.5
# T       0.276918 -0.730732
# TM      0.221702 -0.559624
# Tm      0.279698 -0.794618
# SLP    -0.292371  0.701662
# H       0.088698 -0.507403
# VV      0.293956 -0.498137
# V       0.827395 -0.446214
# VM      1.000000 -0.310336
# PM 2.5 -0.310336  1.000000

# %% [markdown]
# ### Correlation Matrix with Heatmap
# Correlation states how the features are related to each other or the target variable.
#
# Correlation can be positive (increase in one value of feature increases the value of the target variable) or negative (increase in one value of feature decreases the value of the target variable)
#
# Heatmap makes it easy to identify which features are most related to the target variable, we will plot heatmap of correlated features using the seaborn library.

# %%
import seaborn as sns
#get correlations of each features in dataset
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
corrmat.index
# Out:
# Index(['T', 'TM', 'Tm', 'SLP', 'H', 'VV', 'V', 'VM', 'PM 2.5'], dtype='object')

# %% [markdown]
# ### Feature Importance
# You can get the feature importance of each feature of your dataset by using the feature importance property of the model.
#
# Feature importance gives you a score for each feature of your data, the higher the score more important or relevant is the feature towards your output variable.
#
# Feature importance is an inbuilt class that comes with Tree Based Regressor, we will be using Extra Tree Regressor for extracting the top 10 features for the dataset.

# %%
from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
X.head()
# Out:
#       T    TM    Tm     SLP     H   VV    V    VM
# 0  31.3  34.4  28.1  1001.8  74.0  4.0  8.3  14.8
# 1  30.2  33.6  26.4  1000.9  78.0  3.4  5.6   7.6
# 2  29.0  30.2  28.2  1000.0  91.0  4.0  4.6   7.6
# 3  30.5  34.8  26.8   997.6  77.0  4.0  4.6   9.4
# 4  30.4  32.4  27.6   997.1  79.0  4.0  7.0   9.4

# %%
print(model.feature_importances_)
# Out:
# [0.22457872 0.05754879 0.34259115 0.15457718 0.07248355 0.06864904
#  0.05054322 0.02902836]

# %%
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %% [markdown]
# ### ANN

# %%
sns.distplot(y)
# Out:
# /Users/saditya/opt/anaconda3/envs/tensorflow/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot: xlabel='PM 2.5', ylabel='Density'>

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Part 2 - Now making the ANN!

# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()

# Fitting the ANN to the Training set
model_history=NN_model.fit(X_train, y_train,validation_split=0.33, batch_size = 10, epochs = 100)
# Out:
# Metal device set to: Apple M1
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1152
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  dense_3 (Dense)             (None, 256)               65792
#
#  dense_4 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 166,017
# Trainable params: 166,017
# Non-trainable params: 0
# _________________________________________________________________
# 2022-11-10 09:49:39.356641: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-11-10 09:49:39.357146: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# /Users/saditya/opt/anaconda3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/data_adapter.py:1699: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   return t[start:end]
# Epoch 1/100
# 2022-11-10 09:49:39.616746: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-11-10 09:49:39.882252: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 37/37 [==============================] - 1s 19ms/step - loss: 35.9752 - mean_absolute_error: 35.9752 - val_loss: 35.5483 - val_mean_absolute_error: 35.5483
# Epoch 2/100
#  1/37 [..............................] - ETA: 0s - loss: 45.8900 - mean_absolute_error: 45.8900
# 2022-11-10 09:49:40.668016: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 37/37 [==============================] - 0s 13ms/step - loss: 33.9707 - mean_absolute_error: 33.9707 - val_loss: 36.1625 - val_mean_absolute_error: 36.1625
# Epoch 3/100
# 37/37 [==============================] - 0s 13ms/step - loss: 33.8606 - mean_absolute_error: 33.8606 - val_loss: 37.0541 - val_mean_absolute_error: 37.0541
# Epoch 4/100
# 37/37 [==============================] - 0s 12ms/step - loss: 35.1039 - mean_absolute_error: 35.1039 - val_loss: 35.4868 - val_mean_absolute_error: 35.4868
# Epoch 5/100
# 37/37 [==============================] - 0s 13ms/step - loss: 33.9554 - mean_absolute_error: 33.9554 - val_loss: 34.4076 - val_mean_absolute_error: 34.4076
# Epoch 6/100
# 37/37 [==============================] - 0s 12ms/step - loss: 32.7014 - mean_absolute_error: 32.7014 - val_loss: 35.1406 - val_mean_absolute_error: 35.1406
# Epoch 7/100
# 37/37 [==============================] - 0s 13ms/step - loss: 30.3744 - mean_absolute_error: 30.3744 - val_loss: 26.2614 - val_mean_absolute_error: 26.2614
# Epoch 8/100
# 37/37 [==============================] - 0s 12ms/step - loss: 24.8795 - mean_absolute_error: 24.8795 - val_loss: 26.4322 - val_mean_absolute_error: 26.4322
# Epoch 9/100
# 37/37 [==============================] - 0s 13ms/step - loss: 18.3483 - mean_absolute_error: 18.3483 - val_loss: 20.2929 - val_mean_absolute_error: 20.2929
# Epoch 10/100
# 37/37 [==============================] - 0s 12ms/step - loss: 19.9551 - mean_absolute_error: 19.9551 - val_loss: 19.1879 - val_mean_absolute_error: 19.1879
# Epoch 11/100
# 37/37 [==============================] - 0s 13ms/step - loss: 18.9483 - mean_absolute_error: 18.9483 - val_loss: 22.3307 - val_mean_absolute_error: 22.3307
# Epoch 12/100
# 37/37 [==============================] - 0s 13ms/step - loss: 19.1216 - mean_absolute_error: 19.1216 - val_loss: 19.6375 - val_mean_absolute_error: 19.6375
# Epoch 13/100
# 37/37 [==============================] - 0s 12ms/step - loss: 18.1540 - mean_absolute_error: 18.1540 - val_loss: 24.6126 - val_mean_absolute_error: 24.6126
# Epoch 14/100
# 37/37 [==============================] - 0s 13ms/step - loss: 18.3708 - mean_absolute_error: 18.3708 - val_loss: 19.0726 - val_mean_absolute_error: 19.0726
# Epoch 15/100
# 37/37 [==============================] - 0s 12ms/step - loss: 18.1736 - mean_absolute_error: 18.1736 - val_loss: 18.5770 - val_mean_absolute_error: 18.5770
# Epoch 16/100
# 37/37 [==============================] - 0s 13ms/step - loss: 17.5834 - mean_absolute_error: 17.5834 - val_loss: 18.2299 - val_mean_absolute_error: 18.2299
# Epoch 17/100
# 37/37 [==============================] - 0s 12ms/step - loss: 18.0126 - mean_absolute_error: 18.0126 - val_loss: 18.1758 - val_mean_absolute_error: 18.1758
# Epoch 18/100
# 37/37 [==============================] - 0s 13ms/step - loss: 17.2755 - mean_absolute_error: 17.2755 - val_loss: 18.0793 - val_mean_absolute_error: 18.0793
# Epoch 19/100
# 37/37 [==============================] - 0s 12ms/step - loss: 17.3073 - mean_absolute_error: 17.3073 - val_loss: 18.0446 - val_mean_absolute_error: 18.0446
# Epoch 20/100
# 37/37 [==============================] - 0s 12ms/step - loss: 18.9593 - mean_absolute_error: 18.9593 - val_loss: 18.3709 - val_mean_absolute_error: 18.3709
# Epoch 21/100
# 37/37 [==============================] - 0s 13ms/step - loss: 17.9850 - mean_absolute_error: 17.9850 - val_loss: 22.1905 - val_mean_absolute_error: 22.1905
# Epoch 22/100
# 37/37 [==============================] - 0s 12ms/step - loss: 19.0042 - mean_absolute_error: 19.0042 - val_loss: 22.5508 - val_mean_absolute_error: 22.5508
# Epoch 23/100
# 37/37 [==============================] - 0s 13ms/step - loss: 22.1236 - mean_absolute_error: 22.1236 - val_loss: 19.6483 - val_mean_absolute_error: 19.6483
# Epoch 24/100
# 37/37 [==============================] - 0s 12ms/step - loss: 17.3817 - mean_absolute_error: 17.3817 - val_loss: 17.9850 - val_mean_absolute_error: 17.9850
# Epoch 25/100
# 37/37 [==============================] - 0s 12ms/step - loss: 17.1825 - mean_absolute_error: 17.1825 - val_loss: 19.8729 - val_mean_absolute_error: 19.8729
# Epoch 26/100
# 37/37 [==============================] - 0s 13ms/step - loss: 19.1188 - mean_absolute_error: 19.1188 - val_loss: 18.0492 - val_mean_absolute_error: 18.0492
# Epoch 27/100
# 37/37 [==============================] - 0s 13ms/step - loss: 17.1604 - mean_absolute_error: 17.1604 - val_loss: 17.9411 - val_mean_absolute_error: 17.9411
# Epoch 28/100
# 37/37 [==============================] - 0s 13ms/step - loss: 17.1490 - mean_absolute_error: 17.1490 - val_loss: 17.9256 - val_mean_absolute_error: 17.9256
# Epoch 29/100
# 37/37 [==============================] - 0s 13ms/step - loss: 17.1424 - mean_absolute_error: 17.1424 - val_loss: 19.0548 - val_mean_absolute_error: 19.0548
# Epoch 30/100
# 37/37 [==============================] - 0s 13ms/step - loss: 19.3828 - mean_absolute_error: 19.3828 - val_loss: 19.0289 - val_mean_absolute_error: 19.0289
# Epoch 31/100
# 37/37 [==============================] - 0s 13ms/step - loss: 17.6183 - mean_absolute_error: 17.6183 - val_loss: 18.7267 - val_mean_absolute_error: 18.7267
# Epoch 32/100
# 37/37 [==============================] - 0s 13ms/step - loss: 18.9300 - mean_absolute_error: 18.9300 - val_loss: 24.4355 - val_mean_absolute_error: 24.4355
# Epoch 33/100
# 37/37 [==============================] - 0s 12ms/step - loss: 18.9177 - mean_absolute_error: 18.9177 - val_loss: 19.0161 - val_mean_absolute_error: 19.0161
# Epoch 34/100
# 37/37 [==============================] - 0s 13ms/step - loss: 17.3907 - mean_absolute_error: 17.3907 - val_loss: 17.9734 - val_mean_absolute_error: 17.9734
# Epoch 35/100
# 37/37 [==============================] - 0s 13ms/step - loss: 17.6266 - mean_absolute_error: 17.6266 - val_loss: 17.8671 - val_mean_absolute_error: 17.8671
# Epoch 36/100
# 37/37 [==============================] - 0s 13ms/step - loss: 17.4178 - mean_absolute_error: 17.4178 - val_loss: 19.0128 - val_mean_absolute_error: 19.0128
# Epoch 37/100
# 37/37 [==============================] - 0s 12ms/step - loss: 16.9702 - mean_absolute_error: 16.9702 - val_loss: 17.8572 - val_mean_absolute_error: 17.8572
# Epoch 38/100
# 37/37 [==============================] - 0s 12ms/step - loss: 17.7953 - mean_absolute_error: 17.7953 - val_loss: 17.7643 - val_mean_absolute_error: 17.7643
# Epoch 39/100
# 37/37 [==============================] - 0s 13ms/step - loss: 17.9574 - mean_absolute_error: 17.9574 - val_loss: 17.8005 - val_mean_absolute_error: 17.8005
# Epoch 40/100
# 37/37 [==============================] - 0s 12ms/step - loss: 17.1108 - mean_absolute_error: 17.1108 - val_loss: 17.8184 - val_mean_absolute_error: 17.8184
# Epoch 41/100
# 37/37 [==============================] - 0s 12ms/step - loss: 17.9200 - mean_absolute_error: 17.9200 - val_loss: 19.9032 - val_mean_absolute_error: 19.9032
# Epoch 42/100
# 37/37 [==============================] - 0s 12ms/step - loss: 18.5158 - mean_absolute_error: 18.5158 - val_loss: 18.0714 - val_mean_absolute_error: 18.0714
# Epoch 43/100
# 37/37 [==============================] - 0s 12ms/step - loss: 17.8578 - mean_absolute_error: 17.8578 - val_loss: 18.1733 - val_mean_absolute_error: 18.1733
# Epoch 44/100
# 37/37 [==============================] - 0s 12ms/step - loss: 17.1772 - mean_absolute_error: 17.1772 - val_loss: 18.6790 - val_mean_absolute_error: 18.6790
# Epoch 45/100
# 37/37 [==============================] - 0s 12ms/step - loss: 17.5104 - mean_absolute_error: 17.5104 - val_loss: 19.1943 - val_mean_absolute_error: 19.1943
# Epoch 46/100
# 37/37 [==============================] - 1s 14ms/step - loss: 16.8644 - mean_absolute_error: 16.8644 - val_loss: 17.8728 - val_mean_absolute_error: 17.8728
# Epoch 47/100
# 37/37 [==============================] - 0s 12ms/step - loss: 17.4194 - mean_absolute_error: 17.4194 - val_loss: 17.9771 - val_mean_absolute_error: 17.9771
# Epoch 48/100
# 37/37 [==============================] - 0s 13ms/step - loss: 17.1406 - mean_absolute_error: 17.1406 - val_loss: 18.0789 - val_mean_absolute_error: 18.0789
# Epoch 49/100
# 37/37 [==============================] - 0s 12ms/step - loss: 16.8123 - mean_absolute_error: 16.8123 - val_loss: 18.0019 - val_mean_absolute_error: 18.0019
# Epoch 50/100
# 37/37 [==============================] - 0s 13ms/step - loss: 17.5440 - mean_absolute_error: 17.5440 - val_loss: 18.1115 - val_mean_absolute_error: 18.1115
# Epoch 51/100
# 37/37 [==============================] - 0s 13ms/step - loss: 17.1123 - mean_absolute_error: 17.1123 - val_loss: 18.8173 - val_mean_absolute_error: 18.8173
# Epoch 52/100
# 37/37 [==============================] - 0s 12ms/step - loss: 17.3719 - mean_absolute_error: 17.3719 - val_loss: 17.8181 - val_mean_absolute_error: 17.8181
# Epoch 53/100
# 37/37 [==============================] - 0s 12ms/step - loss: 17.0473 - mean_absolute_error: 17.0473 - val_loss: 18.6588 - val_mean_absolute_error: 18.6588
# Epoch 54/100
# 37/37 [==============================] - 0s 12ms/step - loss: 17.9609 - mean_absolute_error: 17.9609 - val_loss: 19.2614 - val_mean_absolute_error: 19.2614
# Epoch 55/100
# 37/37 [==============================] - 0s 13ms/step - loss: 18.1947 - mean_absolute_error: 18.1947 - val_loss: 18.3129 - val_mean_absolute_error: 18.3129
# Epoch 56/100
# 37/37 [==============================] - 0s 13ms/step - loss: 20.2935 - mean_absolute_error: 20.2935 - val_loss: 18.1055 - val_mean_absolute_error: 18.1055
# Epoch 57/100
# 37/37 [==============================] - 0s 13ms/step - loss: 17.8731 - mean_absolute_error: 17.8731 - val_loss: 20.2521 - val_mean_absolute_error: 20.2521
# Epoch 58/100
# 37/37 [==============================] - 0s 12ms/step - loss: 17.8470 - mean_absolute_error: 17.8470 - val_loss: 19.1519 - val_mean_absolute_error: 19.1519
# Epoch 59/100
# 37/37 [==============================] - 0s 12ms/step - loss: 17.4868 - mean_absolute_error: 17.4868 - val_loss: 19.0442 - val_mean_absolute_error: 19.0442
# Epoch 60/100
# 37/37 [==============================] - 0s 13ms/step - loss: 17.0614 - mean_absolute_error: 17.0614 - val_loss: 20.1546 - val_mean_absolute_error: 20.1546
# Epoch 61/100
# 37/37 [==============================] - 0s 12ms/step - loss: 17.7249 - mean_absolute_error: 17.7249 - val_loss: 17.8250 - val_mean_absolute_error: 17.8250
# Epoch 62/100
# 37/37 [==============================] - 0s 12ms/step - loss: 17.1812 - mean_absolute_error: 17.1812 - val_loss: 17.8933 - val_mean_absolute_error: 17.8933
# Epoch 63/100
# 37/37 [==============================] - 0s 13ms/step - loss: 18.1527 - mean_absolute_error: 18.1527 - val_loss: 18.7323 - val_mean_absolute_error: 18.7323
# Epoch 64/100
# 37/37 [==============================] - 0s 13ms/step - loss: 17.2601 - mean_absolute_error: 17.2601 - val_loss: 17.8630 - val_mean_absolute_error: 17.8630
# Epoch 65/100
# 37/37 [==============================] - 1s 14ms/step - loss: 16.7038 - mean_absolute_error: 16.7038 - val_loss: 17.6794 - val_mean_absolute_error: 17.6794
# Epoch 66/100
# 37/37 [==============================] - 0s 13ms/step - loss: 16.9238 - mean_absolute_error: 16.9238 - val_loss: 17.7591 - val_mean_absolute_error: 17.7591
# Epoch 67/100
# 37/37 [==============================] - 0s 12ms/step - loss: 17.9249 - mean_absolute_error: 17.9249 - val_loss: 18.3305 - val_mean_absolute_error: 18.3305
# Epoch 68/100
# 37/37 [==============================] - 0s 12ms/step - loss: 16.9320 - mean_absolute_error: 16.9320 - val_loss: 18.1171 - val_mean_absolute_error: 18.1171
# Epoch 69/100
# 37/37 [==============================] - 0s 13ms/step - loss: 18.1095 - mean_absolute_error: 18.1095 - val_loss: 17.8152 - val_mean_absolute_error: 17.8152
# Epoch 70/100
# 37/37 [==============================] - 0s 13ms/step - loss: 20.3387 - mean_absolute_error: 20.3387 - val_loss: 19.1618 - val_mean_absolute_error: 19.1618
# Epoch 71/100
# 37/37 [==============================] - 0s 12ms/step - loss: 18.1201 - mean_absolute_error: 18.1201 - val_loss: 17.9945 - val_mean_absolute_error: 17.9945
# Epoch 72/100
# 37/37 [==============================] - 0s 12ms/step - loss: 16.7555 - mean_absolute_error: 16.7555 - val_loss: 17.7015 - val_mean_absolute_error: 17.7015
# Epoch 73/100
# 37/37 [==============================] - 0s 11ms/step - loss: 16.6876 - mean_absolute_error: 16.6876 - val_loss: 17.8171 - val_mean_absolute_error: 17.8171
# Epoch 74/100
# 37/37 [==============================] - 0s 12ms/step - loss: 17.9757 - mean_absolute_error: 17.9757 - val_loss: 17.7799 - val_mean_absolute_error: 17.7799
# Epoch 75/100
# 37/37 [==============================] - 1s 14ms/step - loss: 16.5021 - mean_absolute_error: 16.5021 - val_loss: 18.1827 - val_mean_absolute_error: 18.1827
# Epoch 76/100
# 37/37 [==============================] - 0s 12ms/step - loss: 17.5880 - mean_absolute_error: 17.5880 - val_loss: 18.8052 - val_mean_absolute_error: 18.8052
# Epoch 77/100
# 37/37 [==============================] - 0s 12ms/step - loss: 17.4981 - mean_absolute_error: 17.4981 - val_loss: 17.7066 - val_mean_absolute_error: 17.7066
# Epoch 78/100
# 37/37 [==============================] - 0s 12ms/step - loss: 18.2024 - mean_absolute_error: 18.2024 - val_loss: 18.5660 - val_mean_absolute_error: 18.5660
# Epoch 79/100
# 37/37 [==============================] - 0s 13ms/step - loss: 16.9117 - mean_absolute_error: 16.9117 - val_loss: 18.3108 - val_mean_absolute_error: 18.3108
# Epoch 80/100
# 37/37 [==============================] - 0s 13ms/step - loss: 16.6500 - mean_absolute_error: 16.6500 - val_loss: 17.8716 - val_mean_absolute_error: 17.8716
# Epoch 81/100
# 37/37 [==============================] - 0s 13ms/step - loss: 17.5556 - mean_absolute_error: 17.5556 - val_loss: 18.0341 - val_mean_absolute_error: 18.0341
# Epoch 82/100
# 37/37 [==============================] - 0s 13ms/step - loss: 16.8651 - mean_absolute_error: 16.8651 - val_loss: 18.8451 - val_mean_absolute_error: 18.8451
# Epoch 83/100
# 37/37 [==============================] - 0s 12ms/step - loss: 17.8455 - mean_absolute_error: 17.8455 - val_loss: 17.7830 - val_mean_absolute_error: 17.7830
# Epoch 84/100
# 37/37 [==============================] - 0s 13ms/step - loss: 17.2882 - mean_absolute_error: 17.2882 - val_loss: 17.7643 - val_mean_absolute_error: 17.7643
# Epoch 85/100
# 37/37 [==============================] - 1s 16ms/step - loss: 16.5457 - mean_absolute_error: 16.5457 - val_loss: 17.6647 - val_mean_absolute_error: 17.6647
# Epoch 86/100
# 37/37 [==============================] - 0s 13ms/step - loss: 16.8524 - mean_absolute_error: 16.8524 - val_loss: 17.5850 - val_mean_absolute_error: 17.5850
# Epoch 87/100
# 37/37 [==============================] - 0s 12ms/step - loss: 16.9177 - mean_absolute_error: 16.9177 - val_loss: 18.9802 - val_mean_absolute_error: 18.9802
# Epoch 88/100
# 37/37 [==============================] - 0s 13ms/step - loss: 17.2893 - mean_absolute_error: 17.2893 - val_loss: 18.4900 - val_mean_absolute_error: 18.4900
# Epoch 89/100
# 37/37 [==============================] - 0s 12ms/step - loss: 16.6352 - mean_absolute_error: 16.6352 - val_loss: 17.8760 - val_mean_absolute_error: 17.8760
# Epoch 90/100
# 37/37 [==============================] - 0s 12ms/step - loss: 17.1031 - mean_absolute_error: 17.1031 - val_loss: 18.2243 - val_mean_absolute_error: 18.2243
# Epoch 91/100
# 37/37 [==============================] - 0s 12ms/step - loss: 17.8511 - mean_absolute_error: 17.8511 - val_loss: 17.9188 - val_mean_absolute_error: 17.9188
# Epoch 92/100
# 37/37 [==============================] - 0s 12ms/step - loss: 16.8324 - mean_absolute_error: 16.8324 - val_loss: 17.9864 - val_mean_absolute_error: 17.9864
# Epoch 93/100
# 37/37 [==============================] - 0s 12ms/step - loss: 16.5250 - mean_absolute_error: 16.5250 - val_loss: 17.7123 - val_mean_absolute_error: 17.7123
# Epoch 94/100
# 37/37 [==============================] - 0s 13ms/step - loss: 16.6005 - mean_absolute_error: 16.6005 - val_loss: 18.3661 - val_mean_absolute_error: 18.3661
# Epoch 95/100
# 37/37 [==============================] - 0s 13ms/step - loss: 17.6384 - mean_absolute_error: 17.6384 - val_loss: 18.6128 - val_mean_absolute_error: 18.6128
# Epoch 96/100
# 37/37 [==============================] - 0s 12ms/step - loss: 16.8442 - mean_absolute_error: 16.8442 - val_loss: 17.7018 - val_mean_absolute_error: 17.7018
# Epoch 97/100
# 37/37 [==============================] - 0s 12ms/step - loss: 18.4618 - mean_absolute_error: 18.4618 - val_loss: 18.1181 - val_mean_absolute_error: 18.1181
# Epoch 98/100
# 37/37 [==============================] - 0s 12ms/step - loss: 16.8756 - mean_absolute_error: 16.8756 - val_loss: 17.6999 - val_mean_absolute_error: 17.6999
# Epoch 99/100
# 37/37 [==============================] - 1s 15ms/step - loss: 17.8494 - mean_absolute_error: 17.8494 - val_loss: 17.6383 - val_mean_absolute_error: 17.6383
# Epoch 100/100
# 37/37 [==============================] - 1s 17ms/step - loss: 17.4955 - mean_absolute_error: 17.4955 - val_loss: 17.6493 - val_mean_absolute_error: 17.6493

# %% [markdown]
# ### Model Evaluation

# %%
prediction=NN_model.predict(X_test)
# Out:
# 8/8 [==============================] - 0s 5ms/step
# 2022-11-10 09:50:27.163245: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
y_test
# Out:
# 369    21.99
# 608    51.35
# 401     7.22
# 14     27.63
# 722    12.90
#        ...
# 211    14.27
# 310    30.91
# 165    38.28
# 188    22.99
# 337    11.57
# Name: PM 2.5, Length: 233, dtype: float64

# %%
sns.distplot(y_test.values.reshape(-1,1)-prediction)
# Out:
# /Users/saditya/opt/anaconda3/envs/tensorflow/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot: ylabel='Density'>

# %%
plt.scatter(y_test,prediction)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 16.895113342841807
# MSE: 698.1330331778599
# RMSE: 26.42220719731529

# %%
import pickle

# %%
# open a file, where you ant to store the data
file = open('ann.pkl', 'wb')

# dump information to that file
pickle.dump(NN_model, file)
# Out:
# INFO:tensorflow:Assets written to: ram://cb2d17f1-4d25-4402-8a94-3d8671d8b938/assets

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [33], line 1
# ----> 1 from google.colab import files
#       2 files.download('ann.pkl')
#
# ModuleNotFoundError: No module named 'google.colab'
