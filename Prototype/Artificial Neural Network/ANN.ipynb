# %% [markdown]
# # Artificial Neural Network
# ### Apply ML algorithms
# Linear Regression
# Lasso Regression
# Decision Tree Regressor
# KNN Regressor
# RandomForestRegressor
# Xgboost Regressor
# Huperparameter Tuning
# ANN- Artificial Neural Network

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Real_Combine.csv')

# %%
df.shape
# Out:
# (775, 9)

# %%
## Check for null values

sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df=df.dropna()

# %%
X=df.iloc[:,:-1] ## independent features
y=df.iloc[:,-1] ## dependent features

# %%
## check null values
X.isnull()
# Out:
#          T     TM     Tm    SLP      H     VV      V     VM
# 0    False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...
# 770  False  False  False  False  False  False  False  False
# 771  False  False  False  False  False  False  False  False
# 772  False  False  False  False  False  False  False  False
# 773  False  False  False  False  False  False  False  False
# 774  False  False  False  False  False  False  False  False
#
# [775 rows x 8 columns]

# %%
y.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 770    False
# 771    False
# 772    False
# 773    False
# 774    False
# Name: PM 2.5, Length: 775, dtype: bool

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                T        TM        Tm       SLP         H        VV         V  \
# T       1.000000  0.935524  0.957816 -0.757420  0.266486  0.718663  0.437618
# TM      0.935524  1.000000  0.822246 -0.602902 -0.000672  0.694784  0.355071
# Tm      0.957816  0.822246  1.000000 -0.811434  0.462392  0.671069  0.441991
# SLP    -0.757420 -0.602902 -0.811434  1.000000 -0.541203 -0.563667 -0.450169
# H       0.266486 -0.000672  0.462392 -0.541203  1.000000  0.071798  0.164732
# VV      0.718663  0.694784  0.671069 -0.563667  0.071798  1.000000  0.388416
# V       0.437618  0.355071  0.441991 -0.450169  0.164732  0.388416  1.000000
# VM      0.276918  0.221702  0.279698 -0.292371  0.088698  0.293956  0.827395
# PM 2.5 -0.730732 -0.559624 -0.794618  0.701662 -0.507403 -0.498137 -0.446214
#
#               VM    PM 2.5
# T       0.276918 -0.730732
# TM      0.221702 -0.559624
# Tm      0.279698 -0.794618
# SLP    -0.292371  0.701662
# H       0.088698 -0.507403
# VV      0.293956 -0.498137
# V       0.827395 -0.446214
# VM      1.000000 -0.310336
# PM 2.5 -0.310336  1.000000

# %% [markdown]
# ### Correlation Matrix with Heatmap
# Correlation states how the features are related to each other or the target variable.
#
# Correlation can be positive (increase in one value of feature increases the value of the target variable) or negative (increase in one value of feature decreases the value of the target variable)
#
# Heatmap makes it easy to identify which features are most related to the target variable, we will plot heatmap of correlated features using the seaborn library.

# %%
import seaborn as sns
#get correlations of each features in dataset
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
corrmat.index
# Out:
# Index(['T', 'TM', 'Tm', 'SLP', 'H', 'VV', 'V', 'VM', 'PM 2.5'], dtype='object')

# %% [markdown]
# ### Feature Importance
# You can get the feature importance of each feature of your dataset by using the feature importance property of the model.
#
# Feature importance gives you a score for each feature of your data, the higher the score more important or relevant is the feature towards your output variable.
#
# Feature importance is an inbuilt class that comes with Tree Based Regressor, we will be using Extra Tree Regressor for extracting the top 10 features for the dataset.

# %%
from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
X.head()
# Out:
#       T    TM    Tm     SLP     H   VV    V    VM
# 0  31.3  34.4  28.1  1001.8  74.0  4.0  8.3  14.8
# 1  30.2  33.6  26.4  1000.9  78.0  3.4  5.6   7.6
# 2  29.0  30.2  28.2  1000.0  91.0  4.0  4.6   7.6
# 3  30.5  34.8  26.8   997.6  77.0  4.0  4.6   9.4
# 4  30.4  32.4  27.6   997.1  79.0  4.0  7.0   9.4

# %%
print(model.feature_importances_)
# Out:
# [0.20020634 0.06374506 0.32675849 0.18749359 0.07540149 0.06683013
#  0.05148077 0.02808413]

# %%
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %% [markdown]
# ### ANN

# %%
sns.distplot(y)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Part 2 - Now making the ANN!

# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()

# Fitting the ANN to the Training set
model_history=NN_model.fit(X_train, y_train,validation_split=0.33, batch_size = 10, epochs = 100)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 128)               1152
#
#  dense_11 (Dense)            (None, 256)               33024
#
#  dense_12 (Dense)            (None, 256)               65792
#
#  dense_13 (Dense)            (None, 256)               65792
#
#  dense_14 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 166,017
# Trainable params: 166,017
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 37/37 [==============================] - 1s 10ms/step - loss: 37.1940 - mean_absolute_error: 37.1940 - val_loss: 35.5884 - val_mean_absolute_error: 35.5884
# Epoch 2/100
# 37/37 [==============================] - 0s 7ms/step - loss: 34.8634 - mean_absolute_error: 34.8634 - val_loss: 35.2650 - val_mean_absolute_error: 35.2650
# Epoch 3/100
# 37/37 [==============================] - 0s 5ms/step - loss: 33.6054 - mean_absolute_error: 33.6054 - val_loss: 34.5946 - val_mean_absolute_error: 34.5946
# Epoch 4/100
# 37/37 [==============================] - 0s 6ms/step - loss: 34.1721 - mean_absolute_error: 34.1721 - val_loss: 36.7747 - val_mean_absolute_error: 36.7747
# Epoch 5/100
# 37/37 [==============================] - 0s 5ms/step - loss: 34.2765 - mean_absolute_error: 34.2765 - val_loss: 33.4030 - val_mean_absolute_error: 33.4030
# Epoch 6/100
# 37/37 [==============================] - 0s 6ms/step - loss: 32.9288 - mean_absolute_error: 32.9288 - val_loss: 34.2996 - val_mean_absolute_error: 34.2996
# Epoch 7/100
# 37/37 [==============================] - 0s 6ms/step - loss: 30.2528 - mean_absolute_error: 30.2528 - val_loss: 28.5242 - val_mean_absolute_error: 28.5242
# Epoch 8/100
# 37/37 [==============================] - 0s 6ms/step - loss: 22.5383 - mean_absolute_error: 22.5383 - val_loss: 18.6171 - val_mean_absolute_error: 18.6171
# Epoch 9/100
# 37/37 [==============================] - 0s 6ms/step - loss: 18.8431 - mean_absolute_error: 18.8431 - val_loss: 18.6144 - val_mean_absolute_error: 18.6144
# Epoch 10/100
# 37/37 [==============================] - 0s 7ms/step - loss: 18.2346 - mean_absolute_error: 18.2346 - val_loss: 19.1896 - val_mean_absolute_error: 19.1896
# Epoch 11/100
# 37/37 [==============================] - 0s 5ms/step - loss: 20.7534 - mean_absolute_error: 20.7534 - val_loss: 22.0392 - val_mean_absolute_error: 22.0392
# Epoch 12/100
# 37/37 [==============================] - 0s 7ms/step - loss: 17.6270 - mean_absolute_error: 17.6270 - val_loss: 18.2591 - val_mean_absolute_error: 18.2591
# Epoch 13/100
# 37/37 [==============================] - 0s 6ms/step - loss: 17.6659 - mean_absolute_error: 17.6659 - val_loss: 19.2779 - val_mean_absolute_error: 19.2779
# Epoch 14/100
# 37/37 [==============================] - 0s 6ms/step - loss: 19.2497 - mean_absolute_error: 19.2497 - val_loss: 18.7812 - val_mean_absolute_error: 18.7812
# Epoch 15/100
# 37/37 [==============================] - 0s 6ms/step - loss: 17.1171 - mean_absolute_error: 17.1171 - val_loss: 18.0947 - val_mean_absolute_error: 18.0947
# Epoch 16/100
# 37/37 [==============================] - 0s 7ms/step - loss: 17.7726 - mean_absolute_error: 17.7726 - val_loss: 18.2175 - val_mean_absolute_error: 18.2175
# Epoch 17/100
# 37/37 [==============================] - 0s 6ms/step - loss: 19.4208 - mean_absolute_error: 19.4208 - val_loss: 24.0289 - val_mean_absolute_error: 24.0289
# Epoch 18/100
# 37/37 [==============================] - 0s 5ms/step - loss: 19.3621 - mean_absolute_error: 19.3621 - val_loss: 19.4038 - val_mean_absolute_error: 19.4038
# Epoch 19/100
# 37/37 [==============================] - 0s 5ms/step - loss: 17.7803 - mean_absolute_error: 17.7803 - val_loss: 19.7481 - val_mean_absolute_error: 19.7481
# Epoch 20/100
# 37/37 [==============================] - 0s 6ms/step - loss: 18.9935 - mean_absolute_error: 18.9935 - val_loss: 21.6992 - val_mean_absolute_error: 21.6992
# Epoch 21/100
# 37/37 [==============================] - 0s 5ms/step - loss: 18.0052 - mean_absolute_error: 18.0052 - val_loss: 18.3758 - val_mean_absolute_error: 18.3758
# Epoch 22/100
# 37/37 [==============================] - 0s 5ms/step - loss: 17.9165 - mean_absolute_error: 17.9165 - val_loss: 23.1337 - val_mean_absolute_error: 23.1337
# Epoch 23/100
# 37/37 [==============================] - 0s 6ms/step - loss: 18.2558 - mean_absolute_error: 18.2558 - val_loss: 18.1491 - val_mean_absolute_error: 18.1491
# Epoch 24/100
# 37/37 [==============================] - 0s 5ms/step - loss: 18.0139 - mean_absolute_error: 18.0139 - val_loss: 17.8957 - val_mean_absolute_error: 17.8957
# Epoch 25/100
# 37/37 [==============================] - 0s 5ms/step - loss: 18.5273 - mean_absolute_error: 18.5273 - val_loss: 17.9076 - val_mean_absolute_error: 17.9076
# Epoch 26/100
# 37/37 [==============================] - 0s 6ms/step - loss: 17.4009 - mean_absolute_error: 17.4009 - val_loss: 17.9404 - val_mean_absolute_error: 17.9404
# Epoch 27/100
# 37/37 [==============================] - 0s 7ms/step - loss: 17.1789 - mean_absolute_error: 17.1789 - val_loss: 18.1519 - val_mean_absolute_error: 18.1519
# Epoch 28/100
# 37/37 [==============================] - 0s 7ms/step - loss: 17.6765 - mean_absolute_error: 17.6765 - val_loss: 18.8051 - val_mean_absolute_error: 18.8051
# Epoch 29/100
# 37/37 [==============================] - 0s 7ms/step - loss: 17.8294 - mean_absolute_error: 17.8294 - val_loss: 18.6987 - val_mean_absolute_error: 18.6987
# Epoch 30/100
# 37/37 [==============================] - 0s 6ms/step - loss: 17.0440 - mean_absolute_error: 17.0440 - val_loss: 18.1426 - val_mean_absolute_error: 18.1426
# Epoch 31/100
# 37/37 [==============================] - 0s 6ms/step - loss: 17.6235 - mean_absolute_error: 17.6235 - val_loss: 23.0425 - val_mean_absolute_error: 23.0425
# Epoch 32/100
# 37/37 [==============================] - 0s 7ms/step - loss: 19.3523 - mean_absolute_error: 19.3523 - val_loss: 19.1430 - val_mean_absolute_error: 19.1430
# Epoch 33/100
# 37/37 [==============================] - 0s 7ms/step - loss: 19.1335 - mean_absolute_error: 19.1335 - val_loss: 20.0110 - val_mean_absolute_error: 20.0110
# Epoch 34/100
# 37/37 [==============================] - 0s 6ms/step - loss: 19.7122 - mean_absolute_error: 19.7122 - val_loss: 17.7641 - val_mean_absolute_error: 17.7641
# Epoch 35/100
# 37/37 [==============================] - 0s 7ms/step - loss: 17.2352 - mean_absolute_error: 17.2352 - val_loss: 18.7566 - val_mean_absolute_error: 18.7566
# Epoch 36/100
# 37/37 [==============================] - 0s 6ms/step - loss: 16.9669 - mean_absolute_error: 16.9669 - val_loss: 17.7713 - val_mean_absolute_error: 17.7713
# Epoch 37/100
# 37/37 [==============================] - 0s 7ms/step - loss: 18.4427 - mean_absolute_error: 18.4427 - val_loss: 18.8499 - val_mean_absolute_error: 18.8499
# Epoch 38/100
# 37/37 [==============================] - 0s 7ms/step - loss: 18.4435 - mean_absolute_error: 18.4435 - val_loss: 17.8773 - val_mean_absolute_error: 17.8773
# Epoch 39/100
# 37/37 [==============================] - 0s 6ms/step - loss: 16.8477 - mean_absolute_error: 16.8477 - val_loss: 18.2038 - val_mean_absolute_error: 18.2038
# Epoch 40/100
# 37/37 [==============================] - 0s 6ms/step - loss: 17.1307 - mean_absolute_error: 17.1307 - val_loss: 17.9519 - val_mean_absolute_error: 17.9519
# Epoch 41/100
# 37/37 [==============================] - 0s 6ms/step - loss: 17.0273 - mean_absolute_error: 17.0273 - val_loss: 19.0319 - val_mean_absolute_error: 19.0319
# Epoch 42/100
# 37/37 [==============================] - 0s 6ms/step - loss: 17.7238 - mean_absolute_error: 17.7238 - val_loss: 23.4554 - val_mean_absolute_error: 23.4554
# Epoch 43/100
# 37/37 [==============================] - 0s 6ms/step - loss: 18.2215 - mean_absolute_error: 18.2215 - val_loss: 19.1208 - val_mean_absolute_error: 19.1208
# Epoch 44/100
# 37/37 [==============================] - 0s 6ms/step - loss: 19.8020 - mean_absolute_error: 19.8020 - val_loss: 21.8052 - val_mean_absolute_error: 21.8052
# Epoch 45/100
# 37/37 [==============================] - 0s 6ms/step - loss: 17.3175 - mean_absolute_error: 17.3175 - val_loss: 18.6350 - val_mean_absolute_error: 18.6350
# Epoch 46/100
# 37/37 [==============================] - 0s 6ms/step - loss: 16.8343 - mean_absolute_error: 16.8343 - val_loss: 18.2137 - val_mean_absolute_error: 18.2137
# Epoch 47/100
# 37/37 [==============================] - 0s 5ms/step - loss: 17.5861 - mean_absolute_error: 17.5861 - val_loss: 17.6934 - val_mean_absolute_error: 17.6934
# Epoch 48/100
# 37/37 [==============================] - 0s 7ms/step - loss: 17.2848 - mean_absolute_error: 17.2848 - val_loss: 18.1616 - val_mean_absolute_error: 18.1616
# Epoch 49/100
# 37/37 [==============================] - 0s 6ms/step - loss: 16.9320 - mean_absolute_error: 16.9320 - val_loss: 17.6168 - val_mean_absolute_error: 17.6168
# Epoch 50/100
# 37/37 [==============================] - 0s 6ms/step - loss: 18.1571 - mean_absolute_error: 18.1571 - val_loss: 20.7177 - val_mean_absolute_error: 20.7177
# Epoch 51/100
# 37/37 [==============================] - 0s 6ms/step - loss: 19.2615 - mean_absolute_error: 19.2615 - val_loss: 22.0424 - val_mean_absolute_error: 22.0424
# Epoch 52/100
# 37/37 [==============================] - 0s 7ms/step - loss: 18.7126 - mean_absolute_error: 18.7126 - val_loss: 19.5413 - val_mean_absolute_error: 19.5413
# Epoch 53/100
# 37/37 [==============================] - 0s 6ms/step - loss: 16.9670 - mean_absolute_error: 16.9670 - val_loss: 18.5543 - val_mean_absolute_error: 18.5543
# Epoch 54/100
# 37/37 [==============================] - 0s 6ms/step - loss: 17.6123 - mean_absolute_error: 17.6123 - val_loss: 17.6531 - val_mean_absolute_error: 17.6531
# Epoch 55/100
# 37/37 [==============================] - 0s 5ms/step - loss: 17.9677 - mean_absolute_error: 17.9677 - val_loss: 18.4142 - val_mean_absolute_error: 18.4142
# Epoch 56/100
# 37/37 [==============================] - 0s 6ms/step - loss: 17.6349 - mean_absolute_error: 17.6349 - val_loss: 19.7202 - val_mean_absolute_error: 19.7202
# Epoch 57/100
# 37/37 [==============================] - 0s 7ms/step - loss: 17.7201 - mean_absolute_error: 17.7201 - val_loss: 17.7100 - val_mean_absolute_error: 17.7100
# Epoch 58/100
# 37/37 [==============================] - 0s 6ms/step - loss: 17.6599 - mean_absolute_error: 17.6599 - val_loss: 18.2889 - val_mean_absolute_error: 18.2889
# Epoch 59/100
# 37/37 [==============================] - 0s 6ms/step - loss: 17.2057 - mean_absolute_error: 17.2057 - val_loss: 18.1343 - val_mean_absolute_error: 18.1343
# Epoch 60/100
# 37/37 [==============================] - 0s 5ms/step - loss: 17.6001 - mean_absolute_error: 17.6001 - val_loss: 17.6828 - val_mean_absolute_error: 17.6828
# Epoch 61/100
# 37/37 [==============================] - 0s 6ms/step - loss: 16.6932 - mean_absolute_error: 16.6932 - val_loss: 18.5955 - val_mean_absolute_error: 18.5955
# Epoch 62/100
# 37/37 [==============================] - 0s 5ms/step - loss: 17.0007 - mean_absolute_error: 17.0007 - val_loss: 17.6754 - val_mean_absolute_error: 17.6754
# Epoch 63/100
# 37/37 [==============================] - 0s 6ms/step - loss: 17.1475 - mean_absolute_error: 17.1475 - val_loss: 18.5122 - val_mean_absolute_error: 18.5122
# Epoch 64/100
# 37/37 [==============================] - 0s 5ms/step - loss: 16.8843 - mean_absolute_error: 16.8843 - val_loss: 17.5471 - val_mean_absolute_error: 17.5471
# Epoch 65/100
# 37/37 [==============================] - 0s 6ms/step - loss: 16.9356 - mean_absolute_error: 16.9356 - val_loss: 17.8186 - val_mean_absolute_error: 17.8186
# Epoch 66/100
# 37/37 [==============================] - 0s 6ms/step - loss: 17.7379 - mean_absolute_error: 17.7379 - val_loss: 18.5131 - val_mean_absolute_error: 18.5131
# Epoch 67/100
# 37/37 [==============================] - 0s 5ms/step - loss: 16.7632 - mean_absolute_error: 16.7632 - val_loss: 19.4793 - val_mean_absolute_error: 19.4793
# Epoch 68/100
# 37/37 [==============================] - 0s 5ms/step - loss: 17.8328 - mean_absolute_error: 17.8328 - val_loss: 17.9281 - val_mean_absolute_error: 17.9281
# Epoch 69/100
# 37/37 [==============================] - 0s 6ms/step - loss: 16.9657 - mean_absolute_error: 16.9657 - val_loss: 17.6565 - val_mean_absolute_error: 17.6565
# Epoch 70/100
# 37/37 [==============================] - 0s 6ms/step - loss: 18.9150 - mean_absolute_error: 18.9150 - val_loss: 17.6875 - val_mean_absolute_error: 17.6875
# Epoch 71/100
# 37/37 [==============================] - 0s 6ms/step - loss: 16.7846 - mean_absolute_error: 16.7846 - val_loss: 17.8824 - val_mean_absolute_error: 17.8824
# Epoch 72/100
# 37/37 [==============================] - 0s 6ms/step - loss: 16.8679 - mean_absolute_error: 16.8679 - val_loss: 17.6118 - val_mean_absolute_error: 17.6118
# Epoch 73/100
# 37/37 [==============================] - 0s 6ms/step - loss: 16.9001 - mean_absolute_error: 16.9001 - val_loss: 17.9049 - val_mean_absolute_error: 17.9049
# Epoch 74/100
# 37/37 [==============================] - 0s 6ms/step - loss: 17.5037 - mean_absolute_error: 17.5037 - val_loss: 18.1255 - val_mean_absolute_error: 18.1255
# Epoch 75/100
# 37/37 [==============================] - 0s 5ms/step - loss: 16.8916 - mean_absolute_error: 16.8916 - val_loss: 17.5599 - val_mean_absolute_error: 17.5599
# Epoch 76/100
# 37/37 [==============================] - 0s 5ms/step - loss: 16.7664 - mean_absolute_error: 16.7664 - val_loss: 17.4797 - val_mean_absolute_error: 17.4797
# Epoch 77/100
# 37/37 [==============================] - 0s 7ms/step - loss: 16.4316 - mean_absolute_error: 16.4316 - val_loss: 19.3959 - val_mean_absolute_error: 19.3959
# Epoch 78/100
# 37/37 [==============================] - 0s 5ms/step - loss: 16.9037 - mean_absolute_error: 16.9037 - val_loss: 17.4432 - val_mean_absolute_error: 17.4432
# Epoch 79/100
# 37/37 [==============================] - 0s 6ms/step - loss: 17.2987 - mean_absolute_error: 17.2987 - val_loss: 17.5488 - val_mean_absolute_error: 17.5488
# Epoch 80/100
# 37/37 [==============================] - 0s 6ms/step - loss: 17.8604 - mean_absolute_error: 17.8604 - val_loss: 20.5266 - val_mean_absolute_error: 20.5266
# Epoch 81/100
# 37/37 [==============================] - 0s 7ms/step - loss: 18.9463 - mean_absolute_error: 18.9463 - val_loss: 22.6009 - val_mean_absolute_error: 22.6009
# Epoch 82/100
# 37/37 [==============================] - 0s 7ms/step - loss: 17.7757 - mean_absolute_error: 17.7757 - val_loss: 18.1313 - val_mean_absolute_error: 18.1313
# Epoch 83/100
# 37/37 [==============================] - 0s 6ms/step - loss: 16.8807 - mean_absolute_error: 16.8807 - val_loss: 18.9959 - val_mean_absolute_error: 18.9959
# Epoch 84/100
# 37/37 [==============================] - 0s 7ms/step - loss: 18.9662 - mean_absolute_error: 18.9662 - val_loss: 21.2487 - val_mean_absolute_error: 21.2487
# Epoch 85/100
# 37/37 [==============================] - 0s 9ms/step - loss: 17.4457 - mean_absolute_error: 17.4457 - val_loss: 17.9850 - val_mean_absolute_error: 17.9850
# Epoch 86/100
# 37/37 [==============================] - 0s 10ms/step - loss: 17.1606 - mean_absolute_error: 17.1606 - val_loss: 20.4752 - val_mean_absolute_error: 20.4752
# Epoch 87/100
# 37/37 [==============================] - 0s 9ms/step - loss: 17.9922 - mean_absolute_error: 17.9922 - val_loss: 19.1367 - val_mean_absolute_error: 19.1367
# Epoch 88/100
# 37/37 [==============================] - 0s 9ms/step - loss: 17.6773 - mean_absolute_error: 17.6773 - val_loss: 18.2069 - val_mean_absolute_error: 18.2069
# Epoch 89/100
# 37/37 [==============================] - 0s 10ms/step - loss: 17.9012 - mean_absolute_error: 17.9012 - val_loss: 17.5558 - val_mean_absolute_error: 17.5558
# Epoch 90/100
# 37/37 [==============================] - 0s 9ms/step - loss: 16.4692 - mean_absolute_error: 16.4692 - val_loss: 17.8716 - val_mean_absolute_error: 17.8716
# Epoch 91/100
# 37/37 [==============================] - 0s 9ms/step - loss: 16.4773 - mean_absolute_error: 16.4773 - val_loss: 17.5269 - val_mean_absolute_error: 17.5269
# Epoch 92/100
# 37/37 [==============================] - 0s 7ms/step - loss: 17.1768 - mean_absolute_error: 17.1768 - val_loss: 17.6359 - val_mean_absolute_error: 17.6359
# Epoch 93/100
# 37/37 [==============================] - 0s 6ms/step - loss: 16.6297 - mean_absolute_error: 16.6297 - val_loss: 17.6022 - val_mean_absolute_error: 17.6022
# Epoch 94/100
# 37/37 [==============================] - 0s 6ms/step - loss: 16.6575 - mean_absolute_error: 16.6575 - val_loss: 17.6600 - val_mean_absolute_error: 17.6600
# Epoch 95/100
# 37/37 [==============================] - 0s 7ms/step - loss: 17.6493 - mean_absolute_error: 17.6493 - val_loss: 17.4538 - val_mean_absolute_error: 17.4538
# Epoch 96/100
# 37/37 [==============================] - 0s 6ms/step - loss: 16.6361 - mean_absolute_error: 16.6361 - val_loss: 17.6609 - val_mean_absolute_error: 17.6609
# Epoch 97/100
# 37/37 [==============================] - 0s 7ms/step - loss: 17.0416 - mean_absolute_error: 17.0416 - val_loss: 17.8105 - val_mean_absolute_error: 17.8105
# Epoch 98/100
# 37/37 [==============================] - 0s 6ms/step - loss: 17.1612 - mean_absolute_error: 17.1612 - val_loss: 17.9140 - val_mean_absolute_error: 17.9140
# Epoch 99/100
# 37/37 [==============================] - 0s 6ms/step - loss: 16.5091 - mean_absolute_error: 16.5091 - val_loss: 17.4357 - val_mean_absolute_error: 17.4357
# Epoch 100/100
# 37/37 [==============================] - 0s 7ms/step - loss: 17.7504 - mean_absolute_error: 17.7504 - val_loss: 18.2497 - val_mean_absolute_error: 18.2497

# %% [markdown]
# ### Model Evaluation

# %%
prediction=NN_model.predict(X_test)
# Out:
# 8/8 [==============================] - 0s 3ms/step

# %%
y_test
# Out:
# 369    21.99
# 608    51.35
# 401     7.22
# 14     27.63
# 722    12.90
#        ...
# 211    14.27
# 310    30.91
# 165    38.28
# 188    22.99
# 337    11.57
# Name: PM 2.5, Length: 233, dtype: float64

# %%
sns.distplot(y_test.values.reshape(-1,1)-prediction)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.scatter(y_test,prediction)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 17.592170258714408
# MSE: 648.7962741474239
# RMSE: 25.47147962226427

# %%
import pickle

# %%
# open a file, where you ant to store the data
file = open('ann.pkl', 'wb')

# dump information to that file
pickle.dump(NN_model, file)

# %%
from google.colab import files
files.download('ann.pkl')
